# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleyorrr/Bi_Atacarejo/blob/main/analise_simulada_atacarejo_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Análise de dados – Simulação Cordeiro Atacarejo
# Simulações de dados do Cordeiro Atacarejo

# %%
# ✅ Bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 📦 Dados simulados do Cordeiro Atacarejo
dados = {
    "Data": pd.date_range("2024-01-01", periods=6, freq="M"),
    "Total_Vendas_Mensal": [1600000, 1620000, 1580000, 1655000, 1700000, 1750000],
    "Clientes_Atendidos": [42000, 41500, 40000, 43500, 44500, 46000],
    "Custo_Estoque": [720000, 740000, 710000, 735000, 755000, 780000],
    "Perdas_Pereciveis": [17000, 18500, 19000, 17200, 19800, 20000],
    "Funcionarios_Ativos": [165, 166, 167, 168, 170, 172],
    "Avaliacoes_Positivas": [84, 86, 87, 89, 91, 93],
}

df = pd.DataFrame(dados)
df["Ticket_Medio"] = df["Total_Vendas_Mensal"] / df["Clientes_Atendidos"]
df["%_Perdas"] = (df["Perdas_Pereciveis"] / df["Total_Vendas_Mensal"]) * 100
df["Vendas_por_Funcionario"] = df["Total_Vendas_Mensal"] / df["Funcionarios_Ativos"]
df.head()
# Out:
# /tmp/ipython-input-2-188939367.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   "Data": pd.date_range("2024-01-01", periods=6, freq="M"),
#         Data  Total_Vendas_Mensal  Clientes_Atendidos  Custo_Estoque  \
# 0 2024-01-31              1600000               42000         720000
# 1 2024-02-29              1620000               41500         740000
# 2 2024-03-31              1580000               40000         710000
# 3 2024-04-30              1655000               43500         735000
# 4 2024-05-31              1700000               44500         755000
#
#    Perdas_Pereciveis  Funcionarios_Ativos  Avaliacoes_Positivas  Ticket_Medio  \
# 0              17000                  165                    84     38.095238
# 1              18500                  166                    86     39.036145
# 2              19000                  167                    87     39.500000
# ...

# %%
# 📈 Vendas Mensais
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="Data", y="Total_Vendas_Mensal", marker="o", color="green")
plt.title("Total de Vendas Mensal")
plt.ylabel("R$")
plt.xticks(rotation=45)
plt.show()

# %%
# 📊 Vendas por Funcionário
plt.figure(figsize=(10, 5))
sns.barplot(data=df, x="Data", y="Vendas_por_Funcionario", color="steelblue")
plt.title("Vendas por Funcionário")
plt.ylabel("R$")
plt.xticks(rotation=45)
plt.show()

# %%
# 🟣 Pizza - Avaliações Positivas
avaliacoes = df["Avaliacoes_Positivas"]
meses = df["Data"].dt.strftime('%b/%Y')
plt.figure(figsize=(8, 8))
plt.pie(avaliacoes, labels=meses, autopct='%1.1f%%', startangle=140)
plt.title("Distribuição das Avaliações Positivas")
plt.show()

# %%
# 📉 Análise: Mês com maior perda
maior_perda = df[df["Perdas_Pereciveis"] == df["Perdas_Pereciveis"].max()]
print("Mês com maior perda:")
print(maior_perda[["Data", "Perdas_Pereciveis"]])
# Out:
# Mês com maior perda:
#         Data  Perdas_Pereciveis
# 5 2024-06-30              20000
